# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#import os
# !pip install ultralytics
import numpy
import ultralytics
from ultralytics import YOLO
#from PIL import Image
#import cv2


WORK_DIR = 'yoloV8pipe/'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### Instantiate model

# %%
# Load a model
#model = YOLO("yolov8l.pt")  # pretrained

name = 'setupCheck'
#PATH = '/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/runs/detect/' + name + '/weights/best.pt'
#model = YOLO(PATH)
#model = YOLO('yolov8s-seg.pt')
model = YOLO("/content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/myRuns/runs/segment/setuCheckTrainWithTest/weights/best.pt")

# %% [markdown]
# ### Train model

# %%
# !ls '/content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg'
# !pwd
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# /content

# %%
#!yolo task=segment mode=train model=yolov8s-seg.pt data="/content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/seg.yaml" epochs=10 imgsz=512

# %%
# Use the model
training = model.train(data="/content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/seg.yaml", epochs=30, name='10p30epochSeg')  # train the model
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# #### Predict

# %%
results = model.predict(source='/content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images', save=True, conf=0.15, show_labels=False)
# Out:
# image 1/15 /content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images/China_MotorBike_000048_jpg.rf.a59c5c5bb35ca4b4f31231929ba4213e.jpg: 640x640 1 cracks, 24.8ms
# image 2/15 /content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images/China_MotorBike_000064_jpg.rf.c42b9817a0262949025106bb285ba821.jpg: 640x640 2 crackss, 24.3ms
# image 3/15 /content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images/China_MotorBike_000069_jpg.rf.77320a0fad0b300558dbf0040ec019e6.jpg: 640x640 1 cracks, 23.9ms
# image 4/15 /content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images/China_MotorBike_000082_jpg.rf.bfb25048701284288dbb0579a0973ed5.jpg: 640x640 3 crackss, 23.9ms
# image 5/15 /content/gdrive/MyDrive/Colab Notebooks/ny/yoloV8pipe/datasets/crackedSeg/test/images/China_MotorBike_000093_jpg.rf.e145f0493bba99b63ae2f81a1e87191b.jpg: 640x640 1 cracks, 23.8ms
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/Colab Notebooks/ny/yoloV8pipe/myRuns'
