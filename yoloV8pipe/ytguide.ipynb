# %%
import os
from ultralytics import YOLO
#from PIL import Image
#import cv2

WORK_DIR = 'yoloV8pipe/'

# %% [markdown]
# ### Instantiate model

# %%
# Load a model
#model = YOLO("yolov8l.pt")  # pretrained

name = 'setupCheck'
#PATH = '/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/runs/detect/' + name + '/weights/best.pt'
#model = YOLO(PATH)
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %% [markdown]
# ### Train model

# %%
# Use the model
training = model.train(data="setupCheck.yaml", epochs=0, name='setupCheckTrain')  # train the model
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.12 torch-2.0.0 CPU
# ...

# %% [markdown]
# #### Predict

# %%
#!ls '/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/runs/detect'
#!ls '/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/detect'

# %%
"""nb = '3' #choose last run
PATH = '/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/runs/detect/train' + nb + '/weights/'"""

# %%
"""#Load best model
model = YOLO(PATH + 'best.pt')
#Predict dataset
results = model.predict(source='/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/Data/test/images',
                        stream=False,
                        save_txt=True,
                        save_conf=True,
                        )#, show=True)"""

# %% [markdown]
# Kjører vha CLI istedet for pythonkode, det gjør at minnebruken holder seg konstant kontra empirisk økende i python.
# Husk å

# %%
# !yolo detect predict model='/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/myRuns/runs/detect/train3/weights/best.pt' source='/content/gdrive/My Drive/Colab Notebooks/TDT4265Project/Data/test/images' save_txt=True save_conf=True
